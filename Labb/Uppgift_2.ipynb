# %%
import pandas as pd
import plotly.express as px

#läste in excel ark + blad samt anv .head() för att få en snabb överblick över bladet
vaccine = pd.read_excel("..\Labb\Data\Folkhalsomyndigheten_Covid19_Vaccine.xlsx", sheet_name = "Vaccinerade kommun och ålder")
vaccine.head()
# Out:
#    Län        Län_namn  Kommun     Kommun_namn  Ålder  Befolkning  \
# 0    1  Stockholms län     114  Upplands Väsby  12-15        2422
# 1    1  Stockholms län     114  Upplands Väsby  16-17        1203
# 2    1  Stockholms län     114  Upplands Väsby  18-29        6692
# 3    1  Stockholms län     114  Upplands Väsby  30-39        7332
# 4    1  Stockholms län     114  Upplands Väsby  40-49        6946
#
#    Antal minst 1 dos  Antal minst 2 doser  Antal 3 doser  Antal 4 doser  \
# 0               1206                 1048            NaN            NaN
# 1                837                  754            NaN            NaN
# 2               4895                 4476         1963.0            NaN
# 3               5558                 5258         2887.0            NaN
# 4               5592                 5432         3725.0            NaN
#
#    Andel minst 1 dos  Andel minst 2 doser  Andel 3 doser  Andel 4 doser
# 0           0.497936             0.432700            NaN            NaN
# 1           0.695761             0.626766            NaN            NaN
# 2           0.731470             0.668858       0.293335            NaN
# 3           0.758047             0.717130       0.393753            NaN
# 4           0.805068             0.782033       0.536280            NaN

# %% [markdown]
# ### a)
# - hur många län finns representerade i datasetet?

# %%
# beräknar de unika värderna samt frekvensen de förekommer
län = vaccine["Län_namn"].value_counts()
län
# Out:
# Västra Götalands län    490
# Skåne län               330
# Stockholms län          260
# Värmlands län           160
# Västerbottens län       150
# Dalarnas län            150
# Norrbottens län         140
# Jönköpings län          130
# Östergötlands län       130
# Kalmar län              120
# Örebro län              120
# Västmanlands län        100
# Gävleborgs län          100
# Södermanlands län        90
# Uppsala län              80
# Kronobergs län           80
# Jämtlands län            80
# Västernorrlands län      70
# Hallands län             60
# Blekinge län             50
# Gotlands län             10
# Name: Län_namn, dtype: int64

# %%
#skriver ut antalet rader i columnen "län", ger oss svar på hur många län som finns representerade i datasetet
län.shape
#svaret är 21 län finns representerade i datasetet
# Out:
# (21,)

# %% [markdown]
# b)
# - Hur många kommuner finns representerade i datasetet?

# %%
# Återupprepade stegen ovan
kommuner = vaccine["Kommun_namn"].value_counts()
kommuner.shape
# Det finns 290 kommuner representerade i datasetet
# Out:
# (290,)

# %% [markdown]
# c)
# - Hur stor är befolkningen som är representerad i datasetet?

# %%
vaccine.head()
# Out:
#    Län        Län_namn  Kommun     Kommun_namn  Ålder  Befolkning  \
# 0    1  Stockholms län     114  Upplands Väsby  12-15        2422
# 1    1  Stockholms län     114  Upplands Väsby  16-17        1203
# 2    1  Stockholms län     114  Upplands Väsby  18-29        6692
# 3    1  Stockholms län     114  Upplands Väsby  30-39        7332
# 4    1  Stockholms län     114  Upplands Väsby  40-49        6946
#
#    Antal minst 1 dos  Antal minst 2 doser  Antal 3 doser  Antal 4 doser  \
# 0               1206                 1048            NaN            NaN
# 1                837                  754            NaN            NaN
# 2               4895                 4476         1963.0            NaN
# 3               5558                 5258         2887.0            NaN
# 4               5592                 5432         3725.0            NaN
#
#    Andel minst 1 dos  Andel minst 2 doser  Andel 3 doser  Andel 4 doser
# 0           0.497936             0.432700            NaN            NaN
# 1           0.695761             0.626766            NaN            NaN
# 2           0.731470             0.668858       0.293335            NaN
# 3           0.758047             0.717130       0.393753            NaN
# 4           0.805068             0.782033       0.536280            NaN

# %%
# summerar värderna av kolumn "Befolkning"
vaccine["Befolkning"].sum()
#Svaret är 9 092 790 personer är representerade i datasetet
# Out:
# 9092790

# %%
#Tar fram frekvenser på varje unikt värde. Vi ser att varje ålderskategori i tabellen innehåller 290 personer.
# Därav är 580 personer under 18 i detta dataset.
vaccine["Ålder"].value_counts()
# Out:
# 12-15             290
# 16-17             290
# 18-29             290
# 30-39             290
# 40-49             290
# 50-59             290
# 60-69             290
# 70-79             290
# 80-89             290
# 90 eller äldre    290
# Name: Ålder, dtype: int64

# %%
#Källa SCB https://www.statistikdatabasen.scb.se/pxweb/sv/ssd/START__BE__BE0101__BE0101A/BefolkningNy/table/tableViewLayout1/
# läste in data

befolkning = pd.read_excel("../Labb/Data/BefolkningSverige.xlsx")
befolkning.head()
# Out:
#   Folkmängd efter region, ålder och år Unnamed: 1  Unnamed: 2
# 0                                  NaN        NaN         NaN
# 1                                  NaN        NaN      2021.0
# 2                             00 Riket     0-4 år    588434.0
# 3                                  NaN     5-9 år    623602.0
# 4                                  NaN   10-14 år    627067.0

# %%
befolkning  = befolkning.drop(0) # började med att städa bort rad 0-1 då de inte innehäll någon information
befolkning
# Out:
#    Folkmängd efter region, ålder och år Unnamed: 1  Unnamed: 2
# 2                              00 Riket     0-4 år    588434.0
# 3                                   NaN     5-9 år    623602.0
# 4                                   NaN   10-14 år    627067.0
# 5                                   NaN   15-19 år    590971.0
# 6                                   NaN   20-24 år    578215.0
# ..                                  ...        ...         ...
# 68                             Databas:        NaN         NaN
# 69                  Statistikdatabasen         NaN         NaN
# 70                                  NaN        NaN         NaN
# 71                  Intern referenskod:        NaN         NaN
# 72                             BE0101N1        NaN         NaN
#
# [71 rows x 3 columns]

# %%
#skapade dataframe med endast de kolumner som var relevanta till upg
df_befolkning = pd.DataFrame(befolkning, columns =["Unnamed: 1", "Unnamed: 2"])
df_befolkning.value_counts()
# Out:
# Unnamed: 1  Unnamed: 2
# 0-4 år      588434.0      1
# 50-54 år    663496.0      1
# 90-94 år    77748.0       1
# 85-89 år    167321.0      1
# 80-84 år    291011.0      1
# 75-79 år    482796.0      1
# 70-74 år    536116.0      1
# 65-69 år    540220.0      1
# 60-64 år    569809.0      1
# 55-59 år    662638.0      1
# 5-9 år      623602.0      1
# 10-14 år    627067.0      1
# 45-49 år    660343.0      1
# 40-44 år    638884.0      1
# 35-39 år    675978.0      1
# 30-34 år    761808.0      1
# 25-29 år    692315.0      1
# 20-24 år    578215.0      1
# 15-19 år    590971.0      1
# 100+ år     2662.0        1
# 95-99 år    20892.0       1
# dtype: int64

# %%
df_befolkning = df_befolkning.sort_values(by = "Unnamed: 1") #sorterade lite
df_befolkning.reset_index # såg till att index nr för raderna kom tillbaka
# Out:
# <bound method DataFrame.reset_index of    Unnamed: 1  Unnamed: 2
# 2      0-4 år    588434.0
# 4    10-14 år    627067.0
# 22    100+ år      2662.0
# 5    15-19 år    590971.0
# 6    20-24 år    578215.0
# ..        ...         ...
# 68        NaN         NaN
# 69        NaN         NaN
# 70        NaN         NaN
# 71        NaN         NaN
# 72        NaN         NaN
#
# [71 rows x 2 columns]>

# %%
df_befolkning = df_befolkning.iloc[:21] #tog ut de rader som innehöll ålders information

# %%
df_befolkning_sorted = df_befolkning.sort_index() # sorterade på rad index
df_befolkning_sorted
# Out:
#    Unnamed: 1  Unnamed: 2
# 2      0-4 år    588434.0
# 3      5-9 år    623602.0
# 4    10-14 år    627067.0
# 5    15-19 år    590971.0
# 6    20-24 år    578215.0
# 7    25-29 år    692315.0
# 8    30-34 år    761808.0
# 9    35-39 år    675978.0
# 10   40-44 år    638884.0
# 11   45-49 år    660343.0
# 12   50-54 år    663496.0
# 13   55-59 år    662638.0
# 14   60-64 år    569809.0
# 15   65-69 år    540220.0
# 16   70-74 år    536116.0
# 17   75-79 år    482796.0
# 18   80-84 år    291011.0
# 19   85-89 år    167321.0
# 20   90-94 år     77748.0
# 21   95-99 år     20892.0
# 22    100+ år      2662.0

# %%
#döpte om kolumner som skulle anv i diagramet nedan
df_population_finale = df_befolkning_sorted.rename(columns={"Unnamed: 1" : "Ålder", "Unnamed: 2": "Mängd"})

# %%
import plotly.express as px
fig = px.bar(df_population_finale, x = "Ålder", y="Mängd", title = "Befolkning ålder i Sverige 2021 - SCB")
fig.show()
fig.write_html("../Labb/Visualiseringar/Befolkning_sverige_2021_ålder.html")

# %% [markdown]
# ### f)
# - Rita stapeldiagram för andel med minst en dos, andel med  två doser per län och tre doser per län

# %%
vaccine.head()
# Out:
#    Län        Län_namn  Kommun     Kommun_namn  Ålder  Befolkning  \
# 0    1  Stockholms län     114  Upplands Väsby  12-15        2422
# 1    1  Stockholms län     114  Upplands Väsby  16-17        1203
# 2    1  Stockholms län     114  Upplands Väsby  18-29        6692
# 3    1  Stockholms län     114  Upplands Väsby  30-39        7332
# 4    1  Stockholms län     114  Upplands Väsby  40-49        6946
#
#    Antal minst 1 dos  Antal minst 2 doser  Antal 3 doser  Antal 4 doser  \
# 0               1206                 1048            NaN            NaN
# 1                837                  754            NaN            NaN
# 2               4895                 4476         1963.0            NaN
# 3               5558                 5258         2887.0            NaN
# 4               5592                 5432         3725.0            NaN
#
#    Andel minst 1 dos  Andel minst 2 doser  Andel 3 doser  Andel 4 doser
# 0           0.497936             0.432700            NaN            NaN
# 1           0.695761             0.626766            NaN            NaN
# 2           0.731470             0.668858       0.293335            NaN
# 3           0.758047             0.717130       0.393753            NaN
# 4           0.805068             0.782033       0.536280            NaN

# %%
# skapar dataframe med de efterfrågade kolumnerna 
vaccine_doses = pd.DataFrame(vaccine, columns = ["Län_namn", "Antal minst 1 dos", "Antal minst 2 doser","Antal 3 doser"])

# %%
vaccine_doses.info() # ger mig en överblick
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2900 entries, 0 to 2899
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Län_namn             2900 non-null   object
#  1   Antal minst 1 dos    2900 non-null   int64
#  2   Antal minst 2 doser  2900 non-null   int64
#  3   Antal 3 doser        2320 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 113.3+ KB

# %%
# grupperar likt föreläsningen om dataframes datan efter "län" och tar därefter fram medelvärdet på samtliga kategorier med metoden.mean("true")
doses_sorted = vaccine_doses.groupby("Län_namn").mean("true").reset_index()
doses_sorted.head()
# Out:
#          Län_namn  Antal minst 1 dos  Antal minst 2 doser  Antal 3 doser
# 0    Blekinge län        2450.380000          2415.240000    2309.300000
# 1    Dalarnas län        1476.240000          1453.513333    1370.408333
# 2    Gotlands län        4878.300000          4793.600000    4686.625000
# 3  Gävleborgs län        2203.760000          2152.710000    1997.275000
# 4    Hallands län        4319.216667          4256.133333    4002.854167

# %%
fig = px.bar(vaccine_doses, x = "Län_namn", y =["Antal minst 1 dos", "Antal minst 2 doser", "Antal 3 doser"], title = "Vaccinationsgrad, doser samt län")
fig.show()
fig.write_html("../Labb/Visualiseringar/Vaccinations_doser_per_lan.html")

#skriver ut diagrammet med användande av tidigare plotly metod samt sparar i min visuals
